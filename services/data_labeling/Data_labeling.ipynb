# %% [markdown]
# # Data labeling
# merge the collected data to one dataset

# %% [markdown]
# ## Imports

# %%
import pandas as pd 
import numpy as np
from os import listdir, remove, path
import plotly.express as px 
from scipy.io import loadmat
import requests
import json
from datetime import datetime
import traceback

# %% [markdown]
# ## Filter and merge 60k images dataset

# %%
path_origin = "../../data/meta/img_60k_origin.csv"
path_new_labels = "../../data/meta/new_labels.csv"

# %%
origin_df = pd.read_csv(path_origin, index_col=0)
origin_df
# Out:
#                   car_name car_type  \
# 0       Acura ILX 4dr 2013      4dr
# 1       Acura ILX 4dr 2013      4dr
# 2       Acura ILX 4dr 2013      4dr
# 3       Acura ILX 4dr 2013      4dr
# 4       Acura ILX 4dr 2013      4dr
# ...                    ...      ...
# 64462  Volvo XC90 SUV 2020      SUV
# 64463  Volvo XC90 SUV 2020      SUV
# 64464  Volvo XC90 SUV 2020      SUV
# 64465  Volvo XC90 SUV 2020      SUV
# 64466  Volvo XC90 SUV 2020      SUV
#
#                                                file_name
# 0      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 1      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 2      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 3      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 4      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# ...                                                  ...
# 64462  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# 64463  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# ...

# %%
filtered_origin = origin_df[~origin_df["car_type"].isin(["4dr", "2dr", "Pickup", "3dr"])]
filtered_origin["car_type"].unique()
# Out:
# array(['SUV', 'Convertible', nan, 'Station Wagon', 'Van'], dtype=object)

# %%
filtered_origin.dropna(inplace=True)
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_9772\3946563298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_origin.dropna(inplace=True)

# %%
filtered_origin["car_type"].unique()
# Out:
# array(['SUV', 'Convertible', 'Station Wagon', 'Van'], dtype=object)

# %%
filtered_origin.drop("car_name", axis=1, inplace=True)
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_9772\3318949361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_origin.drop("car_name", axis=1, inplace=True)

# %%
filtered_origin = filtered_origin[["file_name", "car_type"]]
filtered_origin
# Out:
#                                                file_name car_type
# 176    Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...      SUV
# 177    Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...      SUV
# 178    Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...      SUV
# 179    Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...      SUV
# 180    Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...      SUV
# ...                                                  ...      ...
# 64462  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...      SUV
# 64463  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...      SUV
# 64464  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...      SUV
# 64465  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...      SUV
# 64466  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...      SUV
#
# [29610 rows x 2 columns]

# %%
new_labels_df = pd.read_csv(path_new_labels)
new_labels_df
# Out:
#                                                file_name              car_type
# 0      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 1      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 2      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 3      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 4      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# ...                                                  ...                   ...
# 21307  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21308  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21309  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21310  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21311  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
#
# ...

# %%
# merge the filtered_origin with the new labels 
appened_df = filtered_origin.append(new_labels_df, ignore_index=True)
appened_df
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_9772\512470584.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   appened_df = filtered_origin.append(new_labels_df, ignore_index=True)
#                                                file_name              car_type
# 0      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...                   SUV
# 1      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...                   SUV
# 2      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...                   SUV
# 3      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...                   SUV
# 4      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...                   SUV
# ...                                                  ...                   ...
# 50917  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# ...

# %% [markdown]
# ## delete files which had an unclear api response (label_checker)

# %%
path_of_files = "../../data/images_2/"
origin_file_names = listdir(path_of_files)
origin_file_names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Car-Body-Prediction\services\data_labeling\Data_labeling.ipynb Cell 15 in 2
#       <a href='vscode-notebook-cell:/d%3A/Car-Body-Prediction/services/data_labeling/Data_labeling.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> path_of_files = "../../data/images_2/"
# ----> <a href='vscode-notebook-cell:/d%3A/Car-Body-Prediction/services/data_labeling/Data_labeling.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> origin_file_names = listdir(path_of_files)
#       <a href='vscode-notebook-cell:/d%3A/Car-Body-Prediction/services/data_labeling/Data_labeling.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> origin_file_names
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../../data/images_2/'

# %%
# files we want to keep
files_to_keep = appened_df["file_name"].to_list()
files_to_keep
# Out:
# ['Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_ARU.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_AWZ.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_AYx.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_bmG.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_BqQ.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_bwH.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_CaE.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_cAL.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_CeP.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_cfN.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_coo.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_EQi.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_EwM.jpg',
#  'Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD_7_4_SUV_Eyo.jpg',
# ...

# %%
origin_file_names = listdir(path_of_files)
origin_file_names
# Out:
# ['Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_aWg.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_Bbw.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_Cvl.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_eeu.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_gQW.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_Gzs.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_kMx.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_Mro.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_Ofi.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_onJ.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_plr.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_RuR.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_SLr.jpg',
#  'Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_UMh.jpg',
# ...

# %%
# deleting the files 
c = 0
for img in origin_file_names: 
    file_path = path.join(path_of_files, img)

    if img not in files_to_keep: 
        remove(file_path)
        c += 1
print(f"{c} files deleted")
# Out:
# 13545 files deleted

# %% [markdown]
# ## stanford dataset

# %%
stanford_path = "../../data/meta/stanford_cars_type.csv"
stanford_origin_df = pd.read_csv(stanford_path, index_col=0)
stanford_origin_df
# Out:
#       file_name  car_code                                car_name  \
# 0     00001.jpg        14                     Audi TTS Coupe 2012
# 1     00002.jpg         3                     Acura TL Sedan 2012
# 2     00003.jpg        91              Dodge Dakota Club Cab 2007
# 3     00004.jpg       134        Hyundai Sonata Hybrid Sedan 2012
# 4     00005.jpg       106     Ford F-450 Super Duty Crew Cab 2012
# ...         ...       ...                                     ...
# 8139  08140.jpg        78  Chrysler Town and Country Minivan 2012
# 8140  08141.jpg       196           smart fortwo Convertible 2012
# 8141  08142.jpg       163       Mercedes-Benz SL-Class Coupe 2009
# 8142  08143.jpg       112                      Ford GT Coupe 2006
# 8143  08144.jpg        17                     Audi 100 Sedan 1994
#
#               brand     car_type  \
# 0              Audi        Coupe
# 1             Acura        Sedan
# 2             Dodge          Cab
# 3           Hyundai        Sedan
# ...

# %%
filtered_stanford = stanford_origin_df[stanford_origin_df["car_type"] != "Other"]
filtered_stanford
# Out:
#       file_name  car_code                                car_name  \
# 0     00001.jpg        14                     Audi TTS Coupe 2012
# 1     00002.jpg         3                     Acura TL Sedan 2012
# 2     00003.jpg        91              Dodge Dakota Club Cab 2007
# 3     00004.jpg       134        Hyundai Sonata Hybrid Sedan 2012
# 4     00005.jpg       106     Ford F-450 Super Duty Crew Cab 2012
# ...         ...       ...                                     ...
# 8139  08140.jpg        78  Chrysler Town and Country Minivan 2012
# 8140  08141.jpg       196           smart fortwo Convertible 2012
# 8141  08142.jpg       163       Mercedes-Benz SL-Class Coupe 2009
# 8142  08143.jpg       112                      Ford GT Coupe 2006
# 8143  08144.jpg        17                     Audi 100 Sedan 1994
#
#               brand     car_type  \
# 0              Audi        Coupe
# 1             Acura        Sedan
# 2             Dodge          Cab
# 3           Hyundai        Sedan
# ...

# %%
filtered_stanford = filtered_stanford.drop(["file_name", "car_code", "car_name", "brand"], axis=1)
filtered_stanford
# Out:
#          car_type                                      new_filename
# 0           Coupe                     00001_Audi TTS Coupe 2012.jpg
# 1           Sedan                     00002_Acura TL Sedan 2012.jpg
# 2             Cab              00003_Dodge Dakota Club Cab 2007.jpg
# 3           Sedan        00004_Hyundai Sonata Hybrid Sedan 2012.jpg
# 4             Cab     00005_Ford F-450 Super Duty Crew Cab 2012.jpg
# ...           ...                                               ...
# 8139      Minivan  08140_Chrysler Town and Country Minivan 2012.jpg
# 8140  Convertible           08141_smart fortwo Convertible 2012.jpg
# 8141        Coupe       08142_Mercedes-Benz SL-Class Coupe 2009.jpg
# 8142        Coupe                      08143_Ford GT Coupe 2006.jpg
# 8143        Sedan                     08144_Audi 100 Sedan 1994.jpg
#
# [7535 rows x 2 columns]

# %%
filtered_stanford.rename(columns={"new_filename": "file_name"}, inplace=True)
filtered_stanford
# Out:
#          car_type                                         file_name
# 0           Coupe                     00001_Audi TTS Coupe 2012.jpg
# 1           Sedan                     00002_Acura TL Sedan 2012.jpg
# 2             Cab              00003_Dodge Dakota Club Cab 2007.jpg
# 3           Sedan        00004_Hyundai Sonata Hybrid Sedan 2012.jpg
# 4             Cab     00005_Ford F-450 Super Duty Crew Cab 2012.jpg
# ...           ...                                               ...
# 8139      Minivan  08140_Chrysler Town and Country Minivan 2012.jpg
# 8140  Convertible           08141_smart fortwo Convertible 2012.jpg
# 8141        Coupe       08142_Mercedes-Benz SL-Class Coupe 2009.jpg
# 8142        Coupe                      08143_Ford GT Coupe 2006.jpg
# 8143        Sedan                     08144_Audi 100 Sedan 1994.jpg
#
# [7535 rows x 2 columns]

# %%
filtered_stanford = filtered_stanford[["file_name", "car_type"]]
filtered_stanford
# Out:
#                                              file_name     car_type
# 0                        00001_Audi TTS Coupe 2012.jpg        Coupe
# 1                        00002_Acura TL Sedan 2012.jpg        Sedan
# 2                 00003_Dodge Dakota Club Cab 2007.jpg          Cab
# 3           00004_Hyundai Sonata Hybrid Sedan 2012.jpg        Sedan
# 4        00005_Ford F-450 Super Duty Crew Cab 2012.jpg          Cab
# ...                                                ...          ...
# 8139  08140_Chrysler Town and Country Minivan 2012.jpg      Minivan
# 8140           08141_smart fortwo Convertible 2012.jpg  Convertible
# 8141       08142_Mercedes-Benz SL-Class Coupe 2009.jpg        Coupe
# 8142                      08143_Ford GT Coupe 2006.jpg        Coupe
# 8143                     08144_Audi 100 Sedan 1994.jpg        Sedan
#
# [7535 rows x 2 columns]

# %%
df = appened_df.append(filtered_stanford, ignore_index=True)
df
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_13592\2784813886.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = appened_df.append(filtered_stanford, ignore_index=True)
#                                                file_name     car_type
# 0      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 1      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 2      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 3      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 4      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# ...                                                  ...          ...
# 58452   08140_Chrysler Town and Country Minivan 2012.jpg      Minivan
# 58453            08141_smart fortwo Convertible 2012.jpg  Convertible
# 58454        08142_Mercedes-Benz SL-Class Coupe 2009.jpg        Coupe
# ...

# %%
df["car_type"].value_counts()
# Out:
# SUV                             21803
# Convertible                      8583
# Sedan                            5090
# Midsize Cars                     4651
# Compact Cars                     2625
# Hatchback                        1900
# Coupe                            1662
# Pickup                           1651
# Standard Pickup Trucks           1642
# Van                              1624
# Large Cars                       1446
# Subcompact Cars                  1436
# Small Pickup Trucks               805
# Cab                               719
# Two Seaters                       676
# Small Station Wagons              536
# Crossover                         413
# Station Wagon                     395
# Wagon                             291
# Minivan                           250
# Mini Compact Cars                 200
# Small Sport Utility Vehicles       43
# Name: car_type, dtype: int64

# %%
df = df[df["car_type"] != "Not Available"]
counts_of_labels = df["car_type"].value_counts()
counts_of_labels
# Out:
# SUV                             21803
# Convertible                      8583
# Sedan                            5090
# Midsize Cars                     4651
# Compact Cars                     2625
# Hatchback                        1900
# Coupe                            1662
# Pickup                           1651
# Standard Pickup Trucks           1642
# Van                              1624
# Large Cars                       1446
# Subcompact Cars                  1436
# Small Pickup Trucks               805
# Cab                               719
# Two Seaters                       676
# Small Station Wagons              536
# Crossover                         413
# Station Wagon                     395
# Wagon                             291
# Minivan                           250
# Mini Compact Cars                 200
# Small Sport Utility Vehicles       43
# Name: car_type, dtype: int64

# %% [markdown]
# ## plot the labels to barchart

# %%
fig = px.bar(x=counts_of_labels.index, y= counts_of_labels.values)

# Customize the background color
fig.update_layout(
    plot_bgcolor='darkgrey',
    paper_bgcolor='black',
    title="Counts of labels", 
    title_font=dict(color='white'), 
    xaxis_title="Label",
    yaxis_title="Count", 
)
# Customize the color of bars
fig.update_traces(marker_color='black')

# Customize the color of labels
fig.update_layout(
    xaxis=dict(tickfont=dict(color='white', size=13)),
    yaxis=dict(tickfont=dict(color='white', size=13))
)
fig.show()

# %% [markdown]
# ## copied all pictures from stanford_cars_type to images_2 folder and renamed to "images" this folder is now the dataset

# %%
df.to_csv("../../data/meta/dataset.csv", index=False)

# %%
ds_path = "../../data/meta/dataset.csv"
ds = pd.read_csv(ds_path)
ds
# Out:
#                                                file_name     car_type
# 0      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 1      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 2      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 3      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# 4      Acura_MDX_2011_42_18_300_37_6_78_68_191_16_AWD...          SUV
# ...                                                  ...          ...
# 58436   08140_Chrysler Town and Country Minivan 2012.jpg      Minivan
# 58437            08141_smart fortwo Convertible 2012.jpg  Convertible
# 58438        08142_Mercedes-Benz SL-Class Coupe 2009.jpg        Coupe
# 58439                       08143_Ford GT Coupe 2006.jpg        Coupe
# 58440                      08144_Audi 100 Sedan 1994.jpg        Sedan
#
# [58441 rows x 2 columns]

# %% [markdown]
# ## Unfortuantely there are lot of images which can not be used for training. we have decided to switch the dataset again (see label checker notebook )
