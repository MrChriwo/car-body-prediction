# %% [markdown]
# # Labeling of data
# using the Stanford_cars_type dataset & 60k images data set

# %% [markdown]
# ## Imports

# %%
from os import listdir
import traceback
import pandas as pd 
import requests
import json
from datetime import datetime

# %% [markdown]
# ## Import and overview of stanford_cars_type data

# %%
cars_type_path = "../../data/meta/stanford_cars_type.csv"
cars_type_df = pd.read_csv(cars_type_path, index_col=0)
cars_type_df
# Out:
#       file_name  car_code                                car_name  \
# 0     00001.jpg        14                     Audi TTS Coupe 2012
# 1     00002.jpg         3                     Acura TL Sedan 2012
# 2     00003.jpg        91              Dodge Dakota Club Cab 2007
# 3     00004.jpg       134        Hyundai Sonata Hybrid Sedan 2012
# 4     00005.jpg       106     Ford F-450 Super Duty Crew Cab 2012
# ...         ...       ...                                     ...
# 8139  08140.jpg        78  Chrysler Town and Country Minivan 2012
# 8140  08141.jpg       196           smart fortwo Convertible 2012
# 8141  08142.jpg       163       Mercedes-Benz SL-Class Coupe 2009
# 8142  08143.jpg       112                      Ford GT Coupe 2006
# 8143  08144.jpg        17                     Audi 100 Sedan 1994
#
#               brand     car_type  \
# 0              Audi        Coupe
# 1             Acura        Sedan
# 2             Dodge          Cab
# 3           Hyundai        Sedan
# 4              Ford          Cab
# ...             ...          ...
# 8139       Chrysler      Minivan
# 8140          smart  Convertible
# 8141  Mercedes-Benz        Coupe
# 8142           Ford        Coupe
# 8143           Audi        Sedan
#
#                                           new_filename
# 0                        00001_Audi TTS Coupe 2012.jpg
# 1                        00002_Acura TL Sedan 2012.jpg
# 2                 00003_Dodge Dakota Club Cab 2007.jpg
# 3           00004_Hyundai Sonata Hybrid Sedan 2012.jpg
# 4        00005_Ford F-450 Super Duty Crew Cab 2012.jpg
# ...                                                ...
# 8139  08140_Chrysler Town and Country Minivan 2012.jpg
# 8140           08141_smart fortwo Convertible 2012.jpg
# 8141       08142_Mercedes-Benz SL-Class Coupe 2009.jpg
# 8142                      08143_Ford GT Coupe 2006.jpg
# 8143                     08144_Audi 100 Sedan 1994.jpg
#
# [8144 rows x 6 columns]

# %%
# drop unnessecary columns 
cars_type_cleaned_cols = cars_type_df.drop(["file_name", "car_code", "brand"], axis="columns")
cars_type_cleaned_cols
# Out:
#                                     car_name     car_type  \
# 0                        Audi TTS Coupe 2012        Coupe
# 1                        Acura TL Sedan 2012        Sedan
# 2                 Dodge Dakota Club Cab 2007          Cab
# 3           Hyundai Sonata Hybrid Sedan 2012        Sedan
# 4        Ford F-450 Super Duty Crew Cab 2012          Cab
# ...                                      ...          ...
# 8139  Chrysler Town and Country Minivan 2012      Minivan
# 8140           smart fortwo Convertible 2012  Convertible
# 8141       Mercedes-Benz SL-Class Coupe 2009        Coupe
# 8142                      Ford GT Coupe 2006        Coupe
# 8143                     Audi 100 Sedan 1994        Sedan
#
#                                           new_filename
# 0                        00001_Audi TTS Coupe 2012.jpg
# 1                        00002_Acura TL Sedan 2012.jpg
# 2                 00003_Dodge Dakota Club Cab 2007.jpg
# 3           00004_Hyundai Sonata Hybrid Sedan 2012.jpg
# 4        00005_Ford F-450 Super Duty Crew Cab 2012.jpg
# ...                                                ...
# 8139  08140_Chrysler Town and Country Minivan 2012.jpg
# 8140           08141_smart fortwo Convertible 2012.jpg
# 8141       08142_Mercedes-Benz SL-Class Coupe 2009.jpg
# 8142                      08143_Ford GT Coupe 2006.jpg
# 8143                     08144_Audi 100 Sedan 1994.jpg
#
# [8144 rows x 3 columns]

# %%
# count values of labels 
cars_type_cleaned_cols["car_type"].value_counts()
# Out:
# Sedan          1907
# SUV            1437
# Coupe          1088
# Convertible    1036
# Cab             719
# Other           609
# Hatchback       554
# Wagon           291
# Van             253
# Minivan         250
# Name: car_type, dtype: int64

# %% [markdown]
# ## Overview of the 60k car images data

# %%
# define dataframe for data
img_60k_path = "../../data/images_2/"
img_60k_names = listdir(img_60k_path)

car_names = []
car_types = []
file_names = []

for i in img_60k_names: 
    split = i.split("_")
    car_names.append(f"{split[0]} {split[1]} {split[-2]} {split[2]}")
    car_types.append(split[-2])
    file_names.append(i)

origin_struct = {"car_name": car_names,
                 "car_type": car_types, 
                 "file_name": file_names}

img_60k_df_origin = pd.DataFrame(origin_struct)
img_60k_df_origin
# Out:
#                   car_name car_type  \
# 0       Acura ILX 4dr 2013      4dr
# 1       Acura ILX 4dr 2013      4dr
# 2       Acura ILX 4dr 2013      4dr
# 3       Acura ILX 4dr 2013      4dr
# 4       Acura ILX 4dr 2013      4dr
# ...                    ...      ...
# 64462  Volvo XC90 SUV 2020      SUV
# 64463  Volvo XC90 SUV 2020      SUV
# 64464  Volvo XC90 SUV 2020      SUV
# 64465  Volvo XC90 SUV 2020      SUV
# 64466  Volvo XC90 SUV 2020      SUV
#
#                                                file_name
# 0      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 1      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 2      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 3      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# 4      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...
# ...                                                  ...
# 64462  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# 64463  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# 64464  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# 64465  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
# 64466  Volvo_XC90_2020_50_19_250_20_4_79_69_194_18_AW...
#
# [64467 rows x 3 columns]

# %%
img_60k_df_origin_path = "../../data/meta/img_60k_origin.csv"
img_60k_df_origin.to_csv(img_60k_df_origin_path)

# %%
# count values of labels in the origin dataset 
img_60k_df_origin["car_type"].value_counts()
# Out:
# 4dr              21144
# SUV              20297
# Convertible       7547
# 2dr               6596
# Pickup            6173
# Van               1371
# nan                733
# Station Wagon      395
# 3dr                211
# Name: car_type, dtype: int64

# %% [markdown]
# ### Because there are many records in [4dr, 2dr, 3dr, Pickup] which are very general we will try to get more information about these records by querying an api

# %%
# obj = list of responaw objects / dicts / json
def are_all_equal(obj: list) -> bool: 
    condition = obj[0]["model_body"]
    for i in obj:
        if i["model_body"] != condition: 
            return False
    return True

headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"}

#storing new car_type in list 
new_body = []

#storing unclear responses in list
unclear_response = []

# if there are any errors while calling api, log them in list - see except block
excep_log = []

totals = len(img_60k_names)
done = 0

for name in img_60k_names: 
    split = name.split("_")

    # define the api call payload
    payload = {
        "make": split[0],
        "model": split[1],
        "year": split[2]
    }

    # just calling api for the mentioned labels
    request_conditions = ["4dr", "2dr", "3dr", "Pickup"]

    if split[-2] in request_conditions:
        try: 
            # calling the api with the created payload and http-header
            response = requests.get("https://www.carqueryapi.com/api/0.3/?callback=?&cmd=getTrims&", params=payload, headers=headers)
            res_text = response.text 
            # convert the json into a python dict
            converted_text = "".join(res_text.split('(', 1)[1].rsplit(')', 1)[0])
            response_dict = json.loads(converted_text)

            # check if the given label of the api can be clearly identfied- 
            # if it's not, safe it declare it as unclear response 
            if not are_all_equal(response_dict["Trims"]):
                unclear_response.append(name)
            else: 
                # save the response to its list. 
                # if the response is not empty 
                if len(response_dict["Trims"]) > 0:
                    new_body.append((name, response_dict["Trims"][0]["model_body"]))
                    done += 1
                    print(f"{done} of {totals} are successfully requested", end="\r")

                else:
                    unclear_response.append((name, "empty"))

        # if any critical error occures, log it to the log list 
        except Exception as e: 
                unclear_response.append((name, "traceback"))
                excep_log.append({"error": {"file": name, 
                                            "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                                            "exception": e, 
                                            "response": response_dict, 
                                            "response_length": len(response_dict), 
                                            "traceback": traceback.format_exc()
                                            }})
                continue
# Out:
# 21312 of 64467 are successfully requested

# %% [markdown]
# ## define and create dataframe from succesfully requested data

# %%
names = [i[0] for i in new_body]
body = [i[1] for i in new_body]

struct = {"file_name": names, 
          "car_type": body}

df = pd.DataFrame(struct)
df
# Out:
#                                                file_name              car_type
# 0      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 1      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 2      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 3      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# 4      Acura_ILX_2013_28_16_110_15_4_70_55_179_39_FWD...                 Sedan
# ...                                                  ...                   ...
# 21307  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21308  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21309  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21310  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
# 21311  Volvo_V60_2020_45_18_250_20_4_72_56_187_23_FWD...  Small Station Wagons
#
# [21312 rows x 2 columns]

# %% [markdown]
# ##  print the counts of new labels

# %%
df["car_type"].value_counts()
# Out:
# Midsize Cars                    4651
# Sedan                           3183
# Compact Cars                    2625
# Pickup                          1651
# Standard Pickup Trucks          1642
# Large Cars                      1446
# Subcompact Cars                 1436
# Hatchback                       1346
# Small Pickup Trucks              805
# Two Seaters                      676
# Coupe                            574
# Small Station Wagons             536
# Crossover                        413
# Mini Compact Cars                200
# SUV                               69
# Small Sport Utility Vehicles      43
# Not Available                     16
# Name: car_type, dtype: int64

# %%
# save the new dataframe 
saving_path = "../../data/meta/new_labels.csv"
df.to_csv(saving_path, index=False)

# %% [markdown]
# ## overview of api call failures

# %%
len(unclear_response)
print(unclear_response)
# Out:
# [('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_aWh.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_Axe.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_CEp.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_FKp.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_kgn.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_kls.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_RbN.jpg', 'traceback'), ('Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_wnI.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_AjN.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_BYW.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Bzl.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_CeZ.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_DAF.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_eEC.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_enR.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_ezi.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_FDm.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_FPM.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_HCJ.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_HnK.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_KUC.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Kvz.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_LEf.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_LvV.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_mDq.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Mua.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_MWV.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_MXI.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_mYr.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_nLv.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_nyL.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_pPh.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_pZV.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_QnO.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_qqO.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_RdW.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_RNb.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_rVG.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_SAm.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Sed.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_SsH.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_sYO.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_TST.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_TVV.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Uii.jpg', 'traceback'), ('Alfa Romeo_Giulia_2017_3 ...

# %%
excep_log
# according to the logs, all tracebacks had an empty response. Probably not in api available
# Out:
# [{'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_aWh.jpg',
#    'timestamp': '2023-05-28 11:10:07',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_Axe.jpg',
#    'timestamp': '2023-05-28 11:10:07',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_CEp.jpg',
#    'timestamp': '2023-05-28 11:10:08',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_FKp.jpg',
#    'timestamp': '2023-05-28 11:10:08',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_kgn.jpg',
#    'timestamp': '2023-05-28 11:10:08',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_kls.jpg',
#    'timestamp': '2023-05-28 11:10:09',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_RbN.jpg',
#    'timestamp': '2023-05-28 11:10:09',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_4C_2017_55_17_230_17_4_73_46_157_24_RWD_2_2_2dr_wnI.jpg',
#    'timestamp': '2023-05-28 11:10:09',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_AjN.jpg',
#    'timestamp': '2023-05-28 11:10:10',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_BYW.jpg',
#    'timestamp': '2023-05-28 11:10:10',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Bzl.jpg',
#    'timestamp': '2023-05-28 11:10:11',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_CeZ.jpg',
#    'timestamp': '2023-05-28 11:10:11',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_DAF.jpg',
#    'timestamp': '2023-05-28 11:10:11',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_eEC.jpg',
#    'timestamp': '2023-05-28 11:10:11',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_enR.jpg',
#    'timestamp': '2023-05-28 11:10:12',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_ezi.jpg',
#    'timestamp': '2023-05-28 11:10:12',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_FDm.jpg',
#    'timestamp': '2023-05-28 11:10:12',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_FPM.jpg',
#    'timestamp': '2023-05-28 11:10:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_HCJ.jpg',
#    'timestamp': '2023-05-28 11:10:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_HnK.jpg',
#    'timestamp': '2023-05-28 11:10:14',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_KUC.jpg',
#    'timestamp': '2023-05-28 11:10:14',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Kvz.jpg',
#    'timestamp': '2023-05-28 11:10:14',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_LEf.jpg',
#    'timestamp': '2023-05-28 11:10:15',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_LvV.jpg',
#    'timestamp': '2023-05-28 11:10:15',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_mDq.jpg',
#    'timestamp': '2023-05-28 11:10:15',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Mua.jpg',
#    'timestamp': '2023-05-28 11:10:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_MWV.jpg',
#    'timestamp': '2023-05-28 11:10:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_MXI.jpg',
#    'timestamp': '2023-05-28 11:10:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_mYr.jpg',
#    'timestamp': '2023-05-28 11:10:17',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_nLv.jpg',
#    'timestamp': '2023-05-28 11:10:17',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_nyL.jpg',
#    'timestamp': '2023-05-28 11:10:17',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_pPh.jpg',
#    'timestamp': '2023-05-28 11:10:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_pZV.jpg',
#    'timestamp': '2023-05-28 11:10:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_QnO.jpg',
#    'timestamp': '2023-05-28 11:10:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_qqO.jpg',
#    'timestamp': '2023-05-28 11:10:19',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_RdW.jpg',
#    'timestamp': '2023-05-28 11:10:19',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_RNb.jpg',
#    'timestamp': '2023-05-28 11:10:20',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_rVG.jpg',
#    'timestamp': '2023-05-28 11:10:20',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_SAm.jpg',
#    'timestamp': '2023-05-28 11:10:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Sed.jpg',
#    'timestamp': '2023-05-28 11:10:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_SsH.jpg',
#    'timestamp': '2023-05-28 11:10:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_sYO.jpg',
#    'timestamp': '2023-05-28 11:10:22',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_TST.jpg',
#    'timestamp': '2023-05-28 11:10:22',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_TVV.jpg',
#    'timestamp': '2023-05-28 11:10:23',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Uii.jpg',
#    'timestamp': '2023-05-28 11:10:23',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_VAn.jpg',
#    'timestamp': '2023-05-28 11:10:23',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_vZV.jpg',
#    'timestamp': '2023-05-28 11:10:24',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_wTg.jpg',
#    'timestamp': '2023-05-28 11:10:24',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_wxM.jpg',
#    'timestamp': '2023-05-28 11:10:25',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_xym.jpg',
#    'timestamp': '2023-05-28 11:10:25',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Yfh.jpg',
#    'timestamp': '2023-05-28 11:10:25',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_ywF.jpg',
#    'timestamp': '2023-05-28 11:10:26',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_zkQ.jpg',
#    'timestamp': '2023-05-28 11:10:26',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2017_39_17_280_20_4_73_56_182_23_AWD_5_4_4dr_ZQP.jpg',
#    'timestamp': '2023-05-28 11:10:26',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_aDL.jpg',
#    'timestamp': '2023-05-28 11:10:27',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_BBV.jpg',
#    'timestamp': '2023-05-28 11:10:27',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_BqF.jpg',
#    'timestamp': '2023-05-28 11:10:28',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_cDb.jpg',
#    'timestamp': '2023-05-28 11:10:28',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_CDf.jpg',
#    'timestamp': '2023-05-28 11:10:28',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_CeC.jpg',
#    'timestamp': '2023-05-28 11:10:29',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_CIv.jpg',
#    'timestamp': '2023-05-28 11:10:29',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_Dcf.jpg',
#    'timestamp': '2023-05-28 11:10:30',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_EAY.jpg',
#    'timestamp': '2023-05-28 11:10:30',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_eIV.jpg',
#    'timestamp': '2023-05-28 11:10:30',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_eNl.jpg',
#    'timestamp': '2023-05-28 11:10:31',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_frU.jpg',
#    'timestamp': '2023-05-28 11:10:31',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_gxp.jpg',
#    'timestamp': '2023-05-28 11:10:32',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'Alfa Romeo_Giulia_2020_41_17_280_20_4_73_56_182_23_AWD_5_4_4dr_IOZ.jpg',
#    'timestamp': '2023-05-28 11:10:32',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
# ...
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_rDY.jpg',
#    'timestamp': '2023-05-28 11:27:12',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_RLx.jpg',
#    'timestamp': '2023-05-28 11:27:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_rrN.jpg',
#    'timestamp': '2023-05-28 11:27:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_sMZ.jpg',
#    'timestamp': '2023-05-28 11:27:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_SuH.jpg',
#    'timestamp': '2023-05-28 11:27:13',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_SVk.jpg',
#    'timestamp': '2023-05-28 11:27:14',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_tZi.jpg',
#    'timestamp': '2023-05-28 11:27:14',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_UCn.jpg',
#    'timestamp': '2023-05-28 11:27:15',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_UGG.jpg',
#    'timestamp': '2023-05-28 11:27:15',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_UgN.jpg',
#    'timestamp': '2023-05-28 11:27:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_uKI.jpg',
#    'timestamp': '2023-05-28 11:27:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_VFX.jpg',
#    'timestamp': '2023-05-28 11:27:16',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_vhQ.jpg',
#    'timestamp': '2023-05-28 11:27:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_wkw.jpg',
#    'timestamp': '2023-05-28 11:27:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_WrU.jpg',
#    'timestamp': '2023-05-28 11:27:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_Wvg.jpg',
#    'timestamp': '2023-05-28 11:27:18',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_wWT.jpg',
#    'timestamp': '2023-05-28 11:27:20',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_XVC.jpg',
#    'timestamp': '2023-05-28 11:27:20',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_xZV.jpg',
#    'timestamp': '2023-05-28 11:27:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_YGt.jpg',
#    'timestamp': '2023-05-28 11:27:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_yhe.jpg',
#    'timestamp': '2023-05-28 11:27:21',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  {'error': {'file': 'BMW_5-Series_2011_45_17_240_30_6_73_57_193_22_RWD_5_4_4dr_Yis.jpg',
#    'timestamp': '2023-05-28 11:27:22',
#    'exception': IndexError('list index out of range'),
#    'response': {'Trims': []},
#    'response_length': 1,
#    'traceback': 'Traceback (most recent call last):\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 41, in <module>\n    if not are_all_equal(response_dict["Trims"]):\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Chris\\AppData\\Local\\Temp\\ipykernel_8668\\1707946236.py", line 3, in are_all_equal\n    condition = obj[0]["model_body"]\n                ~~~^^^\nIndexError: list index out of range\n'}},
#  ...]

# %% [markdown]
# ## save failures to txt log file

# %%
path_fails = "./failures.txt"
with open(path_fails, 'w') as fp:
    for item in unclear_response:
        item_str = " ".join(item)
        fp.write(item_str + "\n")
    print('Done')
# Out:
# Done
